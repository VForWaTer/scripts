# %% [markdown]
# # Parsing CUHASI metadata

# %%
import pandas as pd
from pprint import pprint

# %%
raw = pd.read_excel('./data/Metadata_CUHASI/SeriesCatalog_corrected_SH.xlsx')
raw['SiteID'] = raw.SiteID.astype(int)

# %%
variables = pd.read_csv('./data/Metadata_CUHASI/Variables.txt', sep='\t', engine='python')
methods = pd.read_csv('./data/Metadata_CUHASI/Methods.txt', sep='\t', engine="python")
sites = pd.read_csv('./data/Metadata_CUHASI/Sites.txt', sep='\t', engine="python")
sites = sites.where(~sites.SiteID.isnull()).dropna(how='all', axis=0)
sites['SiteID'] = sites.SiteID.astype(int)
sites.where(sites.SiteID==59).dropna()
# Out:
# Empty DataFrame
# Columns: [SiteID, SiteCode, SiteName, LatLongDatumID, Elevation_m, VerticalDatum, LocalX, LocalY, Latitude, Longitude, LocalProjectionID, PosAccuracy_m, State, County, Comments, Unnamed: 15]
# Index: []

# %%
mr = pd.merge(raw, sites, left_on='SiteID', right_on='SiteID', how='inner')
mr = pd.merge(mr, variables, left_on='VariableID', right_on='VariableID', how='inner')
cuhasi = pd.merge(mr, methods, left_on='MethodID', right_on='MethodID', how='inner')
print(cuhasi.shape)
cuhasi.head()
# Out:
# (2353, 59)
#    SeriesID  SiteID               SiteCode_x  \
# 0        55      51  1.1.45.30.2.1.2.CL.SA.a
# 1        56      52  1.1.45.30.2.1.2.CL.SA.b
# 2        57      53  1.1.45.30.2.1.2.CL.SA.c
# 3        58      54  1.1.45.30.2.1.2.CL.SA.d
# 4       117      68  1.1.45.30.2.1.2.CL.SB.a
#
#                                        SiteName_x  VariableID VariableCode_x  \
# 0  schist - cluster: S_A - forest - valley bottom          28            NaN
# 1  schist - cluster: S_A - forest - valley bottom          28            NaN
# 2  schist - cluster: S_A - forest - valley bottom          28            NaN
# 3  schist - cluster: S_A - forest - valley bottom          28            NaN
# 4  schist - cluster: S_A - forest - valley bottom          28            NaN
#
#       VariableName_x    Speciation_x  VariableUnitsID_x VariableUnitsName  \
# 0  Sap Flow velocity  Not Applicable                NaN               NaN
# 1  Sap Flow velocity  Not Applicable                NaN               NaN
# 2  Sap Flow velocity  Not Applicable                NaN               NaN
# 3  Sap Flow velocity  Not Applicable                NaN               NaN
# 4  Sap Flow velocity  Not Applicable                NaN               NaN
#
#    ... SampleMedium_y        ValueType_y  IsRegular  TimeSupport_y  \
# 0  ...           Tree  Field observation          1              5
# 1  ...           Tree  Field observation          1              5
# 2  ...           Tree  Field observation          1              5
# 3  ...           Tree  Field observation          1              5
# 4  ...           Tree  Field observation          1              5
#
#   TimeUnitsID_y DataType_y GeneralCategory_y  NoDataValue  \
# 0           102    Average         Hydrology        -9999
# 1           102    Average         Hydrology        -9999
# 2           102    Average         Hydrology        -9999
# 3           102    Average         Hydrology        -9999
# 4           102    Average         Hydrology        -9999
#
#                                  MethodDescription_y  \
# 0  Sap flow velocity measured with East 30 Sensor...
# 1  Sap flow velocity measured with East 30 Sensor...
# 2  Sap flow velocity measured with East 30 Sensor...
# 3  Sap flow velocity measured with East 30 Sensor...
# 4  Sap flow velocity measured with East 30 Sensor...
#
#                                   MethodLink
# 0  http://www.east30sensors.com/sap-flow.php
# 1  http://www.east30sensors.com/sap-flow.php
# 2  http://www.east30sensors.com/sap-flow.php
# 3  http://www.east30sensors.com/sap-flow.php
# 4  http://www.east30sensors.com/sap-flow.php
#
# [5 rows x 59 columns]

# %%
cuhasi.where(cuhasi.SiteID==59).dropna()
# Out:
# Empty DataFrame
# Columns: [SeriesID, SiteID, SiteCode_x, SiteName_x, VariableID, VariableCode_x, VariableName_x, Speciation_x, VariableUnitsID_x, VariableUnitsName, SampleMedium_x, ValueType_x, TimeSupport_x, TimeUnitsID_x, TimeUnitsName, DataType_x, GeneralCategory_x, MethodID, MethodDescription_x, SourceID, Organization, SourceDescription, Citation, QualityControlLevelID, QualityControlLevelCode, BeginDateTime, EndDateTime, BeginDateTimeUTC, EndDateTimeUTC, ValueCount, SiteCode_y, SiteName_y, LatLongDatumID, Elevation_m, VerticalDatum, LocalX, LocalY, Latitude, Longitude, LocalProjectionID, PosAccuracy_m, State, County, Comments, Unnamed: 15, VariableCode_y, VariableName_y, Speciation_y, VariableUnitsID_y, SampleMedium_y, ValueType_y, IsRegular, TimeSupport_y, TimeUnitsID_y, DataType_y, GeneralCategory_y, NoDataValue, MethodDescription_y, MethodLink]
# Index: []
#
# [0 rows x 59 columns]

# %% [markdown]
# See if there are only instances of `_x` and `_y`, caused by overlapping columns during merge, or if an  `_x_y` happened as well.

# %%
colmapper = {col: col.replace('_x', '').replace('_y', '') for col in cuhasi.columns}
pprint(colmapper)
# Out:
# {'BeginDateTime': 'BeginDateTime',
#  'BeginDateTimeUTC': 'BeginDateTimeUTC',
#  'Citation': 'Citation',
#  'Comments': 'Comments',
#  'County': 'County',
#  'DataType_x': 'DataType',
#  'DataType_y': 'DataType',
#  'Elevation_m': 'Elevation_m',
#  'EndDateTime': 'EndDateTime',
#  'EndDateTimeUTC': 'EndDateTimeUTC',
#  'GeneralCategory_x': 'GeneralCategory',
#  'GeneralCategory_y': 'GeneralCategory',
#  'IsRegular': 'IsRegular',
#  'LatLongDatumID': 'LatLongDatumID',
#  'Latitude': 'Latitude',
#  'LocalProjectionID': 'LocalProjectionID',
#  'LocalX': 'LocalX',
#  'LocalY': 'LocalY',
#  'Longitude': 'Longitude',
#  'MethodDescription_x': 'MethodDescription',
#  'MethodDescription_y': 'MethodDescription',
#  'MethodID': 'MethodID',
#  'MethodLink': 'MethodLink',
#  'NoDataValue': 'NoDataValue',
#  'Organization': 'Organization',
#  'PosAccuracy_m': 'PosAccuracy_m',
#  'QualityControlLevelCode': 'QualityControlLevelCode',
#  'QualityControlLevelID': 'QualityControlLevelID',
#  'SampleMedium_x': 'SampleMedium',
#  'SampleMedium_y': 'SampleMedium',
#  'SeriesID': 'SeriesID',
#  'SiteCode_x': 'SiteCode',
#  'SiteCode_y': 'SiteCode',
#  'SiteID': 'SiteID',
#  'SiteName_x': 'SiteName',
#  'SiteName_y': 'SiteName',
#  'SourceDescription': 'SourceDescription',
#  'SourceID': 'SourceID',
#  'Speciation_x': 'Speciation',
#  'Speciation_y': 'Speciation',
#  'State': 'State',
#  'TimeSupport_x': 'TimeSupport',
#  'TimeSupport_y': 'TimeSupport',
#  'TimeUnitsID_x': 'TimeUnitsID',
#  'TimeUnitsID_y': 'TimeUnitsID',
#  'TimeUnitsName': 'TimeUnitsName',
#  'Unnamed: 15': 'Unnamed: 15',
#  'ValueCount': 'ValueCount',
#  'ValueType_x': 'ValueType',
#  'ValueType_y': 'ValueType',
#  'VariableCode_x': 'VariableCode',
#  'VariableCode_y': 'VariableCode',
#  'VariableID': 'VariableID',
#  'VariableName_x': 'VariableName',
#  'VariableName_y': 'VariableName',
#  'VariableUnitsID_x': 'VariableUnitsID',
#  'VariableUnitsID_y': 'VariableUnitsID',
#  'VariableUnitsName': 'VariableUnitsName',
#  'VerticalDatum': 'VerticalDatum'}

# %% [markdown]
# We can savely delete the `_x` col and and rename the `_y`. Also drop the `Unnamed: 15` column

# %%
for col in cuhasi.columns:
    if col.endswith('_x') or col=='Unnamed: 15':
        cuhasi.drop(col, axis=1, inplace=True)
cols = [col.replace('_y', '') for col in cuhasi.columns]
cuhasi.columns = cols
cuhasi.head()
# Out:
#    SeriesID  SiteID  VariableID VariableUnitsName TimeUnitsName  MethodID  \
# 0        55    51.0          28               NaN        minute        76
# 1        56    52.0          28               NaN        minute        76
# 2        57    53.0          28               NaN        minute        76
# 3        58    54.0          28               NaN        minute        76
# 4       117    68.0          28               NaN        minute        76
#
#    SourceID                                 Organization  \
# 0         5  German Research Centre For Geosciences GFZ
# 1         5  German Research Centre For Geosciences GFZ
# 2         5  German Research Centre For Geosciences GFZ
# 3         5  German Research Centre For Geosciences GFZ
# 4         5  German Research Centre For Geosciences GFZ
#
#          SourceDescription                                           Citation  \
# 0  Sektion 5.4 - Hydrology  Data collected by GFZ as part of the CAOS project
# 1  Sektion 5.4 - Hydrology  Data collected by GFZ as part of the CAOS project
# 2  Sektion 5.4 - Hydrology  Data collected by GFZ as part of the CAOS project
# 3  Sektion 5.4 - Hydrology  Data collected by GFZ as part of the CAOS project
# 4  Sektion 5.4 - Hydrology  Data collected by GFZ as part of the CAOS project
#
#    ...  SampleMedium          ValueType  IsRegular  TimeSupport  TimeUnitsID  \
# 0  ...          Tree  Field observation          1            5          102
# 1  ...          Tree  Field observation          1            5          102
# 2  ...          Tree  Field observation          1            5          102
# 3  ...          Tree  Field observation          1            5          102
# 4  ...          Tree  Field observation          1            5          102
#
#    DataType  GeneralCategory NoDataValue  \
# 0   Average        Hydrology       -9999
# 1   Average        Hydrology       -9999
# 2   Average        Hydrology       -9999
# 3   Average        Hydrology       -9999
# 4   Average        Hydrology       -9999
#
#                                    MethodDescription  \
# 0  Sap flow velocity measured with East 30 Sensor...
# 1  Sap flow velocity measured with East 30 Sensor...
# 2  Sap flow velocity measured with East 30 Sensor...
# 3  Sap flow velocity measured with East 30 Sensor...
# 4  Sap flow velocity measured with East 30 Sensor...
#
#                                   MethodLink
# 0  http://www.east30sensors.com/sap-flow.php
# 1  http://www.east30sensors.com/sap-flow.php
# 2  http://www.east30sensors.com/sap-flow.php
# 3  http://www.east30sensors.com/sap-flow.php
# 4  http://www.east30sensors.com/sap-flow.php
#
# [5 rows x 45 columns]

# %%
cuhasi.to_csv('cuhasi_merged.csv', index=None)
