# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime

# %%
FILENAME = 'Grundigklinik.csv'

# %% [markdown]
# # Read in data

# %% [markdown]
# ## Read in data for the selected year

# %%
# read in data: december before
try:
    data0 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2021\\02_01_21\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert in diesem Pfad nicht.")
# read in data: january
try:
    data1 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2022\\01_23_22\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert in diesem Pfad nicht.")
# read in data: february
try:
    data2 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2022\\02_20_22\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert in diesem Pfad nicht.")
# read in data: march
try:
    data3 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2022\\03_20_22\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert in diesem Pfad nicht.")
# read in data: april
try:
    data4 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2022\\04_29_22\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert in diesem Pfad nicht.")
# read in data: may
try:
    data5 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2022\\05_26_22\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert in diesem Pfad nicht.")
# read in data: june
try:
    data6 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2022\\07_02_22\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert in diesem Pfad nicht.")
# read in data: july
try:
    data7 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2022\\07_30_22\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert in diesem Pfad nicht.")
# read in data: august
try:
    data8 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2022\\08_25_22\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert in diesem Pfad nicht.")
# read in data: september
try:
    data9 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2022\\09_24_22\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert in diesem Pfad nicht.")
# read in data: october
try:
    data10= pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2022\\10_22_22\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert in diesem Pfad nicht.")
# read in data: november
try:
    data11 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2022\\11_19_22\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert in diesem Pfad nicht.")
# read in data: december
try:
    data12 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2022\\12_17_22\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert in diesem Pfad nicht.")
# read in data: january after
try:
    data13 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2023\\01_21_23\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert in diesem Pfad nicht.")

# %% [markdown]
# ## Read in data for the previous year

# %%
# read in data: december before
try:
    data14 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2020\\12_19_20\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert in diesem Pfad nicht.")
# read in data: february
try:
    data15 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2021\\02_01_21\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert in diesem Pfad nicht.")
# read in data: march
try:
    data16 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2021\\03_02_21\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert in diesem Pfad nicht.")
# read in data: april
try:
    data17 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2021\\04_14_21\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert in diesem Pfad nicht.")
# read in data: may
try:
    data18 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2021\\05_08_21\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert in diesem Pfad nicht.")
# read in data: june
try:
    data19 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2021\\06_16_21\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert in diesem Pfad nicht.")
# read in data: july
try:
    data20 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2021\\07_09_21\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert in diesem Pfad nicht.")
# read in data: august
try:
    data21 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2021\\08_12_21\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert in diesem Pfad nicht.")
# read in data: september
try:
    data22 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2021\\09_14_21\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert in diesem Pfad nicht.")
# read in data: november
try:
    data23 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2021\\11_19_21\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert in diesem Pfad nicht.")
# read in data: december
try:
    data24 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2021\\12_10_21\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert in diesem Pfad nicht.")
# read in data: january after
try:
    data25 = pd.read_csv(f'C:\\Users\\flori\\Documents\\Uni Bauingenieurwesen\\Master\\Studentische Hilfskraft Hydrologie\\Daten Bühlot\\Daten-2022\\01_23_22\\preprocessing\\{FILENAME}', index_col=0, parse_dates=True)
except FileNotFoundError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert in diesem Pfad nicht.")
# Out:
# Die Datei 'Grundigklinik.csv' als Variable data20 existiert in diesem Pfad nicht.
# Die Datei 'Grundigklinik.csv' als Variable data21 existiert in diesem Pfad nicht.
# Die Datei 'Grundigklinik.csv' als Variable data23 existiert in diesem Pfad nicht.
# Die Datei 'Grundigklinik.csv' als Variable data24 existiert in diesem Pfad nicht.

# %% [markdown]
# # Graph for the course of temperature

# %% [markdown]
# ## Over the year

# %%
# Diagramm für den Temperaturverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['temperature'], 'b.-', markersize=4, label='selected year') # somehow the line is not being created
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['temperature'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 1, 1), datetime.date(datetime.datetime.now().year-1, 12, 31)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 1, 1), datetime.date(datetime.datetime.now().year-2, 12, 31)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Temperature in °C', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Temperature over Time (Year)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# Die Datei 'Grundigklinik.csv' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Grundigklinik.csv' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Grundigklinik.csv' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Grundigklinik.csv' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.

# %% [markdown]
# ## January

# %%
# Diagramm für den Temperaturverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['temperature'], 'b.-', markersize=4, label='selected year') # somehow the line is not being created
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['temperature'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 1, 1), datetime.date(datetime.datetime.now().year-1, 1, 31)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 1, 1), datetime.date(datetime.datetime.now().year-2, 1, 31)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Temperature in °C', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Temperature over Time (January)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# Die Datei 'Grundigklinik.csv' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Grundigklinik.csv' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Grundigklinik.csv' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Grundigklinik.csv' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.

# %% [markdown]
# ## February

# %%
# Diagramm für den Temperaturverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['temperature'], 'b.-', markersize=4, label='selected year') # somehow the line is not being created
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['temperature'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 2, 1), datetime.date(datetime.datetime.now().year-1, 2, 28)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 2, 1), datetime.date(datetime.datetime.now().year-2, 2, 28)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Temperature in °C', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Temperature over Time (February)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# Die Datei 'Grundigklinik.csv' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Grundigklinik.csv' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Grundigklinik.csv' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Grundigklinik.csv' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.

# %% [markdown]
# ## March

# %%
# Diagramm für den Temperaturverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['temperature'], 'b.-', markersize=4, label='selected year') # somehow the line is not being created
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['temperature'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 3, 1), datetime.date(datetime.datetime.now().year-1, 3, 31)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 3, 1), datetime.date(datetime.datetime.now().year-2, 3, 31)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Temperature in °C', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Temperature over Time (March)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# Die Datei 'Grundigklinik.csv' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Grundigklinik.csv' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Grundigklinik.csv' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Grundigklinik.csv' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.

# %% [markdown]
# ## April

# %%
# Diagramm für den Temperaturverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['temperature'], 'b.-', markersize=4, label='selected year') # somehow the line is not being created
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['temperature'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 4, 1), datetime.date(datetime.datetime.now().year-1, 4, 30)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 4, 1), datetime.date(datetime.datetime.now().year-2, 4, 30)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Temperature in °C', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Temperature over Time (April)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Die Datei 'Schwabenquelle.csv' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# ...

# %% [markdown]
# ## May

# %%
# Diagramm für den Temperaturverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['temperature'], 'b.-', markersize=4, label='selected year') # somehow the line is not being created
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['temperature'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 5, 1), datetime.date(datetime.datetime.now().year-1, 5, 31)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 5, 1), datetime.date(datetime.datetime.now().year-2, 5, 31)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Temperature in °C', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Temperature over Time (May)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Die Datei 'Schwabenquelle.csv' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# ...

# %% [markdown]
# ## June

# %%
# Diagramm für den Temperaturverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['temperature'], 'b.-', markersize=4, label='selected year') # somehow the line is not being created
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['temperature'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 6, 1), datetime.date(datetime.datetime.now().year-1, 6, 30)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 6, 1), datetime.date(datetime.datetime.now().year-2, 6, 30)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Temperature in °C', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Temperature over Time (June)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Die Datei 'Schwabenquelle.csv' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# ...

# %% [markdown]
# ## July

# %%
# Diagramm für den Temperaturverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['temperature'], 'b.-', markersize=4, label='selected year') # somehow the line is not being created
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['temperature'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 7, 1), datetime.date(datetime.datetime.now().year-1, 7, 31)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 7, 1), datetime.date(datetime.datetime.now().year-2, 7, 31)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Temperature in °C', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Temperature over Time (July)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Die Datei 'Schwabenquelle.csv' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# ...

# %% [markdown]
# ## August

# %%
# Diagramm für den Temperaturverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['temperature'], 'b.-', markersize=4, label='selected year') # somehow the line is not being created
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['temperature'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 8, 1), datetime.date(datetime.datetime.now().year-1, 8, 31)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 8, 1), datetime.date(datetime.datetime.now().year-2, 8, 31)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Temperature in °C', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Temperature over Time (August)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Die Datei 'Schwabenquelle.csv' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# ...

# %% [markdown]
# ## September

# %%
# Diagramm für den Temperaturverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['temperature'], 'b.-', markersize=4, label='selected year') # somehow the line is not being created
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['temperature'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 9, 1), datetime.date(datetime.datetime.now().year-1, 9, 30)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 9, 1), datetime.date(datetime.datetime.now().year-2, 9, 30)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Temperature in °C', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Temperature over Time (September)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Die Datei 'Schwabenquelle.csv' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# ...

# %% [markdown]
# ## October

# %%
# Diagramm für den Temperaturverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['temperature'], 'b.-', markersize=4, label='selected year') # somehow the line is not being created
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['temperature'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 10, 1), datetime.date(datetime.datetime.now().year-1, 10, 31)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 10, 1), datetime.date(datetime.datetime.now().year-2, 10, 31)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Temperature in °C', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Temperature over Time (October)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Die Datei 'Schwabenquelle.csv' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# ...

# %% [markdown]
# ## November

# %%
# Diagramm für den Temperaturverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['temperature'], 'b.-', markersize=4, label='selected year') # somehow the line is not being created
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['temperature'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 11, 1), datetime.date(datetime.datetime.now().year-1, 11, 30)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 11, 1), datetime.date(datetime.datetime.now().year-2, 11, 30)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Temperature in °C', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Temperature over Time', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Die Datei 'Schwabenquelle.csv' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# ...

# %% [markdown]
# ## December

# %%
# Diagramm für den Temperaturverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['temperature'], 'b.-', markersize=4, label='selected year') # somehow the line is not being created
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['temperature'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['temperature'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['temperature'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 12, 1), datetime.date(datetime.datetime.now().year-1, 12, 31)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 12, 1), datetime.date(datetime.datetime.now().year-2, 12, 31)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Temperature in °C', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Temperature over Time (December)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Die Datei 'Schwabenquelle.csv' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# ...

# %% [markdown]
# # Graph for the course of rainfall

# %% [markdown]
# ## Over the year

# %%
# Diagramm für den Niederschlagsverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['rainfall'], 'b.-', markersize=4, label='selected year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['rainfall'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 1, 1), datetime.date(datetime.datetime.now().year-1, 12, 31)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 1, 1), datetime.date(datetime.datetime.now().year-2, 12, 31)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Rainfall in mm', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Rainfall over Time (Year)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Die Datei 'Schwabenquelle.csv' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# ...

# %% [markdown]
# ## January

# %%
# Diagramm für den Niederschlagsverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['rainfall'], 'b.-', markersize=4, label='selected year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['rainfall'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 1, 1), datetime.date(datetime.datetime.now().year-1, 1, 31)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 1, 1), datetime.date(datetime.datetime.now().year-2, 1, 31)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Rainfall in mm', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Rainfall over Time (January)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Die Datei 'Schwabenquelle.csv' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# ...

# %% [markdown]
# ## February

# %%
# Diagramm für den Niederschlagsverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['rainfall'], 'b.-', markersize=4, label='selected year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['rainfall'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 2, 1), datetime.date(datetime.datetime.now().year-1, 2, 28)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 2, 1), datetime.date(datetime.datetime.now().year-2, 2, 28)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Rainfall in mm', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Rainfall over Time (February)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Die Datei 'Schwabenquelle.csv' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# ...

# %% [markdown]
# ## March

# %%
# Diagramm für den Niederschlagsverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['rainfall'], 'b.-', markersize=4, label='selected year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['rainfall'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 3, 1), datetime.date(datetime.datetime.now().year-1, 3, 31)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 3, 1), datetime.date(datetime.datetime.now().year-2, 3, 31)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Rainfall in mm', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Rainfall over Time (March)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Die Datei 'Schwabenquelle.csv' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# ...

# %% [markdown]
# ## April

# %%
# Diagramm für den Niederschlagsverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['rainfall'], 'b.-', markersize=4, label='selected year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['rainfall'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 4, 1), datetime.date(datetime.datetime.now().year-1, 4, 30)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 4, 1), datetime.date(datetime.datetime.now().year-2, 4, 30)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Rainfall in mm', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Rainfall over Time (April)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Die Datei 'Schwabenquelle.csv' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# ...

# %% [markdown]
# ## May

# %%
# Diagramm für den Niederschlagsverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['rainfall'], 'b.-', markersize=4, label='selected year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['rainfall'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 5, 1), datetime.date(datetime.datetime.now().year-1, 5, 31)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 5, 1), datetime.date(datetime.datetime.now().year-2, 5, 31)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Rainfall in mm', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Rainfall over Time (May)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Die Datei 'Schwabenquelle.csv' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# ...

# %% [markdown]
# ## June

# %%
# Diagramm für den Niederschlagsverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['rainfall'], 'b.-', markersize=4, label='selected year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['rainfall'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 6, 1), datetime.date(datetime.datetime.now().year-1, 6, 30)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 6, 1), datetime.date(datetime.datetime.now().year-2, 6, 30)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Rainfall in mm', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Rainfall over Time (June)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Die Datei 'Schwabenquelle.csv' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# ...

# %% [markdown]
# ## July

# %%
# Diagramm für den Niederschlagsverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['rainfall'], 'b.-', markersize=4, label='selected year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['rainfall'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 7, 1), datetime.date(datetime.datetime.now().year-1, 7, 31)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 7, 1), datetime.date(datetime.datetime.now().year-2, 7, 31)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Rainfall in mm', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Rainfall over Time (July)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Die Datei 'Schwabenquelle.csv' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# ...

# %% [markdown]
# ## August

# %%
# Diagramm für den Niederschlagsverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['rainfall'], 'b.-', markersize=4, label='selected year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['rainfall'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 8, 1), datetime.date(datetime.datetime.now().year-1, 8, 31)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 8, 1), datetime.date(datetime.datetime.now().year-2, 8, 31)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Rainfall in mm', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Rainfall over Time (August)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Die Datei 'Schwabenquelle.csv' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# ...

# %% [markdown]
# ## September

# %%
# Diagramm für den Niederschlagsverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['rainfall'], 'b.-', markersize=4, label='selected year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['rainfall'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 9, 1), datetime.date(datetime.datetime.now().year-1, 9, 30)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 9, 1), datetime.date(datetime.datetime.now().year-2, 9, 30)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Rainfall in mm', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Rainfall over Time (September)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Die Datei 'Schwabenquelle.csv' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# ...

# %% [markdown]
# ## October

# %%
# Diagramm für den Niederschlagsverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['rainfall'], 'b.-', markersize=4, label='selected year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['rainfall'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 10, 1), datetime.date(datetime.datetime.now().year-1, 10, 31)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 10, 1), datetime.date(datetime.datetime.now().year-2, 10, 31)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Rainfall in mm', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Rainfall over Time (October)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Die Datei 'Schwabenquelle.csv' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# ...

# %% [markdown]
# ## November

# %%
# Diagramm für den Niederschlagsverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['rainfall'], 'b.-', markersize=4, label='selected year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['rainfall'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 11, 1), datetime.date(datetime.datetime.now().year-1, 11, 30)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 11, 1), datetime.date(datetime.datetime.now().year-2, 11, 30)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Rainfall in mm', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Rainfall over Time (November)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Die Datei 'Schwabenquelle.csv' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# ...

# %% [markdown]
# ## December

# %%
# Diagramm für den Niederschlagsverlauf erstellen
fig, ax1 = plt.subplots(figsize=(20, 6))

ax2 = ax1.twiny()

# Daten auf die Achsen plotten
try:
    ax1.plot(data0.index, data0['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data1.index, data1['rainfall'], 'b.-', markersize=4, label='selected year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data2.index, data2['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data3.index, data3['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data3 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data4.index, data4['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data4 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data5.index, data5['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data5 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data6.index, data6['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data6 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data7.index, data7['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data7 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data8.index, data8['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data8 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data9.index, data9['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data9 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data10.index, data10['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data10 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data11.index, data11['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data11 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data12.index, data12['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax1.plot(data13.index, data13['rainfall'], 'b.-', markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")


try:
    ax2.plot(data14.index, data14['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data14 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data15.index, data15['rainfall'], 'r.-', alpha=0.1, markersize=4,  label='previous year')
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data15 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data16.index, data16['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data16 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data17.index, data17['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data17 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data18.index, data18['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data18 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data19.index, data19['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data19 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data20.index, data20['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data20 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data21.index, data21['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data21 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data22.index, data22['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data22 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data23.index, data23['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data23 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data24.index, data24['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data24 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")
try:
    ax2.plot(data25.index, data25['rainfall'], 'r.-', alpha=0.1, markersize=4)
except NameError:
    print(f"Die Datei '{FILENAME}' als Variable data25 existiert nicht und kann somit nicht im Diagramm angezeigt werden.")

# Achsenlimits
ax1.set_xlim([datetime.date(datetime.datetime.now().year-1, 12, 1), datetime.date(datetime.datetime.now().year-1, 12, 31)])
ax2.set_xlim([datetime.date(datetime.datetime.now().year-2, 12, 1), datetime.date(datetime.datetime.now().year-2, 12, 31)])

# Achsenbeschriftungen
ax1.set_xlabel('Date', fontdict={'fontsize': 13}, color='b')
ax1.set_ylabel('Rainfall in mm', fontdict={'fontsize': 13}, color='black')
ax2.set_xlabel('Date', fontdict={'fontsize': 13}, color='r')

# Legenden
leg1 = ax1.legend(loc='upper left')
leg2 = ax2.legend(loc='upper left')

# Position der Legenden anpassen
leg1.set_bbox_to_anchor((0, 0.8, 1, 0.2))
leg2.set_bbox_to_anchor((0, 0.72, 1, 0.2))

plt.title('Rainfall over Time (December)', fontdict={'fontweight':'bold', 'fontsize': 15}, y=1.15)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Die Datei 'Schwabenquelle.csv' als Variable data0 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data1 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data2 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data12 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# Die Datei 'Schwabenquelle.csv' als Variable data13 existiert nicht und kann somit nicht im Diagramm angezeigt werden.
# ...
