# %%
from metacatalog import api
import pandas as pd

# %%
UPLOAD = False
CONNECTION = 'metacatalog'

# %%
session = api.connect_database(CONNECTION)
print(f"using {session.bind}")
# Out:
# using Engine(postgresql://postgres:***@localhost:5432/metacatalog)

# %%
for variable in api.find_variable(session):
    print(variable)
# Out:
# air temperature [C] <ID=1>
# soil temperature [C] <ID=2>
# water temperature [C] <ID=3>
# discharge [m3/s] <ID=4>
# air pressure [10^2*Pa] <ID=5>
# relative humidity [%] <ID=6>
# daily rainfall sum [mm/d] <ID=7>
# rainfall intensity [mm/h] <ID=8>
# solar irradiance [W/m2] <ID=9>
# net radiation [W/m2] <ID=10>
# gravimetric water content [kg/kg] <ID=11>
# volumetric water content [cm3/cm3] <ID=12>
# precision [-] <ID=13>
# sap flow [cm^3/cm^2h] <ID=14>
# matric potential [MPa] <ID=15>
# bulk electrical conductivity [mS/cm] <ID=16>
# specific electrical conductivity [mS/cm] <ID=17>
# river water level [m] <ID=18>
# evapotranspiration [mm/d] <ID=19>
# drainage [mm/d] <ID=20>

# %%
api.find_variable(session, name="air temperature")

# %%
author = api.find_person(session, last_name="Ehret")

if author is None and UPLOAD:
    api.add_person(session, first_name="Uwe", last_name="Ehret", organisation_name="Karlsruhe Institute of Technology", organisation_abbrev="KIT")
# Out:
# []

# %%
raw = pd.read_excel('metadata.xlsx')
raw
# Out:
#                                station        external_ID  \
# 0                         Butschenberg     28.14.04_00_01
# 1                         Butschenberg     28.14.04_00_01
# 2                        Grundigklinik     28.14.02_00_01
# 3                        Grundigklinik     28.14.02_00_01
# 4                             Hundseck     28.12.00_00_02
# 5                             Hundseck     28.12.00_00_02
# 6                             Schafhof     28.13.01_01_01
# 7                             Schafhof     28.13.01_01_01
# 8                           Schönbrunn     28.00.00_00_01
# 9                           Schönbrunn     28.00.00_00_01
# 10  Schwabenquelle /\nSchwabenbrünnele  28.11.03.01_01_02
# 11  Schwabenquelle /\nSchwabenbrünnele  28.11.03.01_01_02
# 12                          Sportplatz     28.15.01_00_01
# 13                          Sportplatz     28.15.01_00_01
# 14             Sternenberg-Schlammfang     28.18.00_00_01
# ...

# %%
meta = raw.copy()

# %%
meta['variable'].unique()
# Out:
# array(['precipitation', 'air temperature', 'electric conductivity',
#        'volumetric water content', 'ground water level',
#        'logger temperature', 'water temperature', 'river water level ',
#        'water conductivity'], dtype=object)

# %%
t = Transformer.from_crs('epsg:31467', 'epsg:4326', always_xy=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12508\4176113879.py in <module>
# ----> 1 t = Transformer.from_crs('epsg:31467', 'epsg:4326', always_xy=True)
#
# NameError: name 'Transformer' is not defined

# %%
meta['location'] = ['SRID=4326;POINT (%f %f)' % t.transform(r[0], r[1]) for i, r in meta [['location_right_value', 'location_high_value']].iterrows()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12508\526395332.py in <module>
# ----> 1 meta['location'] = ['SRID=4326;POINT (%f %f)' % t.transform(r[0], r[1]) for i, r in meta [['location_right_value', 'location_high_value']].iterrows()]
#
# ~\AppData\Local\Temp\ipykernel_12508\526395332.py in <listcomp>(.0)
# ----> 1 meta['location'] = ['SRID=4326;POINT (%f %f)' % t.transform(r[0], r[1]) for i, r in meta [['location_right_value', 'location_high_value']].iterrows()]
#
# NameError: name 't' is not defined
