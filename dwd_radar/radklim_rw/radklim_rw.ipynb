# %% [markdown]
# # RADKLIM RW download and upload to metacatalog, including creation of metadata

# %%
import tarfile
from glob import glob
import os

import tqdm
import xarray as xr
import numpy as np

import radolan_to_netcdf as rtn
#import cf

from metacatalog import api, ext

# %% [markdown]
# ## Download data from DWD CDC server (binary)
#
# 2001 - 2022

# %%
# %%time

# !wget -q -P ./data/raklim_rw_binary/ --show-progress -r -np -A .tar.gz -R "index.html*" https://opendata.dwd.de/climate_environment/CDC/grids_germany/hourly/radolan/reproc/2017_002/bin/
# Out:
# opendata.dwd.de/cli     [ <=>                ]   2,75K  --.-KB/s    in 0s
# opendata.dwd.de/cli     [ <=>                ]   1,80K  --.-KB/s    in 0s
# opendata.dwd.de/cli     [ <=>                ]   1,80K  --.-KB/s    in 0s
# opendata.dwd.de/cli     [ <=>                ]   1,80K  --.-KB/s    in 0s
# opendata.dwd.de/cli     [ <=>                ]   1,80K  --.-KB/s    in 0s
# opendata.dwd.de/cli     [ <=>                ]   1,80K  --.-KB/s    in 0s
# opendata.dwd.de/cli     [ <=>                ]   1,80K  --.-KB/s    in 0s
# opendata.dwd.de/cli     [ <=>                ]   1,80K  --.-KB/s    in 0s
# opendata.dwd.de/cli     [ <=>                ]   1,80K  --.-KB/s    in 0s
# opendata.dwd.de/cli     [ <=>                ]   1,80K  --.-KB/s    in 0s
# opendata.dwd.de/cli     [ <=>                ]   1,80K  --.-KB/s    in 0s
# opendata.dwd.de/cli     [ <=>                ]   1,80K  --.-KB/s    in 0s
# opendata.dwd.de/cli     [ <=>                ]   1,80K  --.-KB/s    in 0s
# opendata.dwd.de/cli     [ <=>                ]   1,80K  --.-KB/s    in 0s
# opendata.dwd.de/cli     [ <=>                ]   1,80K  --.-KB/s    in 0s
# opendata.dwd.de/cli     [ <=>                ]   1,80K  --.-KB/s    in 0s
# opendata.dwd.de/cli     [ <=>                ]   1,80K  --.-KB/s    in 0s
# opendata.dwd.de/cli     [ <=>                ]   1,80K  --.-KB/s    in 0s
# opendata.dwd.de/cli     [ <=>                ]   1,80K  --.-KB/s    in 0s
# opendata.dwd.de/cli     [ <=>                ]   1,80K  --.-KB/s    in 0s
# opendata.dwd.de/cli     [ <=>                ]   1,80K  --.-KB/s    in 0s
# opendata.dwd.de/cli     [ <=>                ]   1,80K  --.-KB/s    in 0s
# opendata.dwd.de/cli     [ <=>                ]     420  --.-KB/s    in 0s
# opendata.dwd.de/cli     [ <=>                ]     436  --.-KB/s    in 0s
# opendata.dwd.de/cli 100%[===================>]  25,12M  11,2MB/s    in 2,2s
# opendata.dwd.de/cli 100%[===================>]  23,49M  11,2MB/s    in 2,1s
# opendata.dwd.de/cli 100%[===================>]  36,62M  11,1MB/s    in 3,3s
# opendata.dwd.de/cli 100%[===================>]  30,55M  10,5MB/s    in 2,9s
# opendata.dwd.de/cli 100%[===================>]  18,06M  11,2MB/s    in 1,6s
# opendata.dwd.de/cli 100%[===================>]  31,34M  11,2MB/s    in 2,8s
# opendata.dwd.de/cli 100%[===================>]  23,79M  11,2MB/s    in 2,1s
# opendata.dwd.de/cli 100%[===================>]  25,48M  11,2MB/s    in 2,3s
# opendata.dwd.de/cli 100%[===================>]  44,83M  11,2MB/s    in 4,2s
# opendata.dwd.de/cli 100%[===================>]  21,26M  11,2MB/s    in 1,9s
# opendata.dwd.de/cli 100%[===================>]  29,12M  11,2MB/s    in 2,6s
# opendata.dwd.de/cli 100%[===================>]  30,68M  11,2MB/s    in 2,7s
# opendata.dwd.de/cli 100%[===================>]  20,74M  10,2MB/s    in 2,0s
# opendata.dwd.de/cli 100%[===================>]  37,46M  11,2MB/s    in 3,4s
# opendata.dwd.de/cli 100%[===================>]  24,03M  11,2MB/s    in 2,2s
# opendata.dwd.de/cli 100%[===================>]  23,40M  11,2MB/s    in 2,1s
# opendata.dwd.de/cli 100%[===================>]  28,86M  10,4MB/s    in 2,8s
# opendata.dwd.de/cli 100%[===================>]  24,74M  11,2MB/s    in 2,2s
# opendata.dwd.de/cli 100%[===================>]  31,85M  11,2MB/s    in 2,9s
# opendata.dwd.de/cli 100%[===================>]  30,44M  11,2MB/s    in 2,7s
# opendata.dwd.de/cli 100%[===================>]  21,78M  10,2MB/s    in 2,1s
# opendata.dwd.de/cli 100%[===================>]  36,29M  11,2MB/s    in 3,2s
# opendata.dwd.de/cli 100%[===================>]  34,71M  11,2MB/s    in 3,1s
# opendata.dwd.de/cli 100%[===================>]  25,04M  11,2MB/s    in 2,2s
# opendata.dwd.de/cli 100%[===================>]  28,58M  10,4MB/s    in 2,7s
# opendata.dwd.de/cli 100%[===================>]  13,32M  11,2MB/s    in 1,2s
# opendata.dwd.de/cli 100%[===================>]  16,15M  11,2MB/s    in 1,4s
# opendata.dwd.de/cli 100%[===================>]  20,38M  11,2MB/s    in 1,8s
# opendata.dwd.de/cli 100%[===================>]  27,71M  11,2MB/s    in 2,5s
# opendata.dwd.de/cli 100%[===================>]  18,60M  10,1MB/s    in 1,8s
# opendata.dwd.de/cli 100%[===================>]  24,18M  11,2MB/s    in 2,2s
# opendata.dwd.de/cli 100%[===================>]  16,26M  11,2MB/s    in 1,5s
# opendata.dwd.de/cli 100%[===================>]  20,18M  11,2MB/s    in 1,8s
# opendata.dwd.de/cli 100%[===================>]  27,28M  11,2MB/s    in 2,4s
# opendata.dwd.de/cli 100%[===================>]  18,58M  9,12MB/s    in 2,0s
# opendata.dwd.de/cli 100%[===================>]  22,59M  11,2MB/s    in 2,0s
# opendata.dwd.de/cli 100%[===================>]  34,64M  11,2MB/s    in 3,1s
# opendata.dwd.de/cli 100%[===================>]  21,84M  11,2MB/s    in 2,0s
# opendata.dwd.de/cli 100%[===================>]  19,63M  11,2MB/s    in 1,8s
# opendata.dwd.de/cli 100%[===================>]  21,05M  10,2MB/s    in 2,1s
# opendata.dwd.de/cli 100%[===================>]  26,50M  11,2MB/s    in 2,4s
# opendata.dwd.de/cli 100%[===================>]  29,47M  11,2MB/s    in 2,6s
# opendata.dwd.de/cli 100%[===================>]  33,67M  11,2MB/s    in 3,0s
# opendata.dwd.de/cli 100%[===================>]  31,30M  10,5MB/s    in 3,0s
# opendata.dwd.de/cli 100%[===================>]  25,06M  11,2MB/s    in 2,2s
# opendata.dwd.de/cli 100%[===================>]  23,89M  11,2MB/s    in 2,1s
# opendata.dwd.de/cli 100%[===================>]  27,35M  11,1MB/s    in 2,5s
# opendata.dwd.de/cli 100%[===================>]  19,89M  11,1MB/s    in 1,8s
# opendata.dwd.de/cli 100%[===================>]  28,85M  11,2MB/s    in 2,6s
# opendata.dwd.de/cli 100%[===================>]  25,26M  11,2MB/s    in 2,3s
# opendata.dwd.de/cli 100%[===================>]  21,80M  10,2MB/s    in 2,1s
# opendata.dwd.de/cli 100%[===================>]  25,29M  11,2MB/s    in 2,3s
# opendata.dwd.de/cli 100%[===================>]  33,35M  11,2MB/s    in 3,0s
# opendata.dwd.de/cli 100%[===================>]  21,14M  11,2MB/s    in 1,9s
# opendata.dwd.de/cli 100%[===================>]  34,61M  11,2MB/s    in 3,1s
# opendata.dwd.de/cli 100%[===================>]  28,94M  11,2MB/s    in 2,6s
# opendata.dwd.de/cli 100%[===================>]  20,98M  10,2MB/s    in 2,1s
# opendata.dwd.de/cli 100%[===================>]  18,35M  11,2MB/s    in 1,6s
# opendata.dwd.de/cli 100%[===================>]  23,15M  11,2MB/s    in 2,1s
# opendata.dwd.de/cli 100%[===================>]  30,83M  11,2MB/s    in 2,8s
# opendata.dwd.de/cli 100%[===================>]  15,65M  11,2MB/s    in 1,4s
# opendata.dwd.de/cli 100%[===================>]  22,53M  11,2MB/s    in 2,0s
# opendata.dwd.de/cli 100%[===================>]  30,99M  11,2MB/s    in 2,8s
# opendata.dwd.de/cli 100%[===================>]  32,50M  11,1MB/s    in 2,9s
# opendata.dwd.de/cli 100%[===================>]  34,82M  10,5MB/s    in 3,3s
# opendata.dwd.de/cli 100%[===================>]  20,06M  11,2MB/s    in 1,8s
# opendata.dwd.de/cli 100%[===================>]  19,70M  11,2MB/s    in 1,8s
# opendata.dwd.de/cli 100%[===================>]  46,10M  11,2MB/s    in 4,1s
# opendata.dwd.de/cli 100%[===================>]  15,45M  11,2MB/s    in 1,4s
# opendata.dwd.de/cli 100%[===================>]  23,94M  10,3MB/s    in 2,3s
# opendata.dwd.de/cli 100%[===================>]  26,78M  11,1MB/s    in 2,4s
# opendata.dwd.de/cli 100%[===================>]  21,73M  11,2MB/s    in 1,9s
# opendata.dwd.de/cli 100%[===================>]  37,96M  11,2MB/s    in 3,4s
# opendata.dwd.de/cli 100%[===================>]  29,26M  11,2MB/s    in 2,6s
# opendata.dwd.de/cli 100%[===================>]  27,67M  10,4MB/s    in 2,7s
# opendata.dwd.de/cli 100%[===================>]   8,94M  10,6MB/s    in 0,8s
# opendata.dwd.de/cli 100%[===================>]  38,62M  11,2MB/s    in 3,5s
# opendata.dwd.de/cli 100%[===================>]  34,26M  11,2MB/s    in 3,1s
# opendata.dwd.de/cli 100%[===================>]  39,64M  10,5MB/s    in 3,7s
# opendata.dwd.de/cli 100%[===================>]  29,28M  11,2MB/s    in 2,6s
# opendata.dwd.de/cli 100%[===================>]  29,59M  11,2MB/s    in 2,6s
# opendata.dwd.de/cli 100%[===================>]  15,96M  11,2MB/s    in 1,4s
# opendata.dwd.de/cli 100%[===================>]  32,59M  11,2MB/s    in 2,9s
# opendata.dwd.de/cli 100%[===================>]  26,03M  10,4MB/s    in 2,5s
# opendata.dwd.de/cli 100%[===================>]  27,42M  11,2MB/s    in 2,5s
# opendata.dwd.de/cli 100%[===================>]  18,29M  11,2MB/s    in 1,6s
# opendata.dwd.de/cli 100%[===================>]  36,78M  11,2MB/s    in 3,3s
# opendata.dwd.de/cli 100%[===================>]  31,37M  10,5MB/s    in 3,0s
# opendata.dwd.de/cli 100%[===================>]  17,06M  11,2MB/s    in 1,5s
# opendata.dwd.de/cli 100%[===================>]  23,74M  11,2MB/s    in 2,1s
# opendata.dwd.de/cli 100%[===================>]  31,62M  11,2MB/s    in 2,8s
# opendata.dwd.de/cli 100%[===================>]  30,21M  11,2MB/s    in 2,7s
# opendata.dwd.de/cli 100%[===================>]  23,47M  10,2MB/s    in 2,3s
# opendata.dwd.de/cli 100%[===================>]  29,66M  11,2MB/s    in 2,7s
# opendata.dwd.de/cli 100%[===================>]  21,62M  11,2MB/s    in 1,9s
# opendata.dwd.de/cli 100%[===================>]  20,69M  11,2MB/s    in 1,9s
# opendata.dwd.de/cli 100%[===================>]  16,82M  11,2MB/s    in 1,5s
# opendata.dwd.de/cli 100%[===================>]  24,16M  10,3MB/s    in 2,3s
# opendata.dwd.de/cli 100%[===================>]  31,41M  11,2MB/s    in 2,8s
# opendata.dwd.de/cli 100%[===================>]  16,67M  11,2MB/s    in 1,5s
# opendata.dwd.de/cli 100%[===================>]  28,60M  11,2MB/s    in 2,6s
# opendata.dwd.de/cli 100%[===================>]  27,10M  10,4MB/s    in 2,6s
# opendata.dwd.de/cli 100%[===================>]  35,53M  11,2MB/s    in 3,2s
# opendata.dwd.de/cli 100%[===================>]  20,28M  11,2MB/s    in 1,8s
# opendata.dwd.de/cli 100%[===================>]  19,02M  11,2MB/s    in 1,7s
# opendata.dwd.de/cli 100%[===================>]  30,01M  10,5MB/s    in 2,9s
# opendata.dwd.de/cli 100%[===================>]  33,67M  11,2MB/s    in 3,0s
# opendata.dwd.de/cli 100%[===================>]  33,14M  11,2MB/s    in 3,0s
# opendata.dwd.de/cli 100%[===================>]  22,56M  11,2MB/s    in 2,0s
# opendata.dwd.de/cli 100%[===================>]  23,20M  10,3MB/s    in 2,3s
# opendata.dwd.de/cli 100%[===================>]  23,92M  11,2MB/s    in 2,1s
# opendata.dwd.de/cli 100%[===================>]  16,92M  11,2MB/s    in 1,5s
# opendata.dwd.de/cli 100%[===================>]  34,00M  11,2MB/s    in 3,0s
# opendata.dwd.de/cli 100%[===================>]  20,28M  11,2MB/s    in 1,8s
# opendata.dwd.de/cli 100%[===================>]  26,05M  10,4MB/s    in 2,5s
# opendata.dwd.de/cli 100%[===================>]  45,43M  11,2MB/s    in 4,1s
# opendata.dwd.de/cli 100%[===================>]  28,76M  11,1MB/s    in 2,6s
# opendata.dwd.de/cli 100%[===================>]  20,10M  11,0MB/s    in 1,8s
# opendata.dwd.de/cli 100%[===================>]  31,98M  11,2MB/s    in 2,9s
# opendata.dwd.de/cli 100%[===================>]  31,25M  11,0MB/s    in 2,8s
# opendata.dwd.de/cli 100%[===================>]  25,81M  10,2MB/s    in 2,5s
# opendata.dwd.de/cli 100%[===================>]  16,14M  11,2MB/s    in 1,4s
# opendata.dwd.de/cli 100%[===================>]  13,98M  11,2MB/s    in 1,3s
# opendata.dwd.de/cli 100%[===================>]  16,05M  11,2MB/s    in 1,4s
# opendata.dwd.de/cli 100%[===================>]  20,88M  11,2MB/s    in 1,9s
# opendata.dwd.de/cli 100%[===================>]  30,29M  10,5MB/s    in 2,9s
# opendata.dwd.de/cli 100%[===================>]  33,98M  11,2MB/s    in 3,0s
# opendata.dwd.de/cli 100%[===================>]  31,83M  11,2MB/s    in 2,8s
# opendata.dwd.de/cli 100%[===================>]  21,31M  11,1MB/s    in 1,9s
# opendata.dwd.de/cli 100%[===================>]  21,31M  10,2MB/s    in 2,1s
# opendata.dwd.de/cli 100%[===================>]   8,36M  11,2MB/s    in 0,7s
# opendata.dwd.de/cli 100%[===================>]  40,16M  11,1MB/s    in 3,6s
# opendata.dwd.de/cli 100%[===================>]  35,21M  11,2MB/s    in 3,2s
# opendata.dwd.de/cli 100%[===================>]  15,12M  11,2MB/s    in 1,4s
# opendata.dwd.de/cli 100%[===================>]  12,26M  11,2MB/s    in 1,1s
# opendata.dwd.de/cli 100%[===================>]  25,68M  10,3MB/s    in 2,5s
# opendata.dwd.de/cli 100%[===================>]  24,74M  11,2MB/s    in 2,2s
# opendata.dwd.de/cli 100%[===================>]  32,86M  11,2MB/s    in 2,9s
# opendata.dwd.de/cli 100%[===================>]  34,95M  11,2MB/s    in 3,1s
# opendata.dwd.de/cli 100%[===================>]  24,92M  10,3MB/s    in 2,4s
# opendata.dwd.de/cli 100%[===================>]  21,74M  11,2MB/s    in 1,9s
# opendata.dwd.de/cli 100%[===================>]  25,23M  11,2MB/s    in 2,3s
# opendata.dwd.de/cli 100%[===================>]  23,87M  11,2MB/s    in 2,1s
# opendata.dwd.de/cli 100%[===================>]  37,67M  11,2MB/s    in 3,4s
# opendata.dwd.de/cli 100%[===================>]  27,58M  10,4MB/s    in 2,7s
# opendata.dwd.de/cli 100%[===================>]  24,08M  11,2MB/s    in 2,2s
# opendata.dwd.de/cli 100%[===================>]  20,34M  11,1MB/s    in 1,8s
# opendata.dwd.de/cli 100%[===================>]  21,33M  11,2MB/s    in 1,9s
# opendata.dwd.de/cli 100%[===================>]  41,04M  11,2MB/s    in 3,7s
# opendata.dwd.de/cli 100%[===================>]  29,40M  10,4MB/s    in 2,8s
# opendata.dwd.de/cli 100%[===================>]  18,24M  11,2MB/s    in 1,6s
# opendata.dwd.de/cli 100%[===================>]  22,04M  11,2MB/s    in 2,0s
# opendata.dwd.de/cli 100%[===================>]  28,57M  11,2MB/s    in 2,6s
# opendata.dwd.de/cli 100%[===================>]  26,97M  11,2MB/s    in 2,4s
# opendata.dwd.de/cli 100%[===================>]  24,91M  10,3MB/s    in 2,4s
# opendata.dwd.de/cli 100%[===================>]  21,90M  11,2MB/s    in 2,0s
# opendata.dwd.de/cli 100%[===================>]  24,11M  11,2MB/s    in 2,2s
# opendata.dwd.de/cli 100%[===================>]  20,30M  11,2MB/s    in 1,8s
# opendata.dwd.de/cli 100%[===================>]  15,62M  11,2MB/s    in 1,4s
# opendata.dwd.de/cli 100%[===================>]  24,93M  9,46MB/s    in 2,6s
# opendata.dwd.de/cli 100%[===================>]  35,93M  11,2MB/s    in 3,2s
# opendata.dwd.de/cli 100%[===================>]  23,55M  11,2MB/s    in 2,1s
# opendata.dwd.de/cli 100%[===================>]  33,75M  11,2MB/s    in 3,0s
# opendata.dwd.de/cli 100%[===================>]  36,67M  10,5MB/s    in 3,5s
# opendata.dwd.de/cli 100%[===================>]  22,57M  11,1MB/s    in 2,0s
# opendata.dwd.de/cli 100%[===================>]  27,34M  11,2MB/s    in 2,4s
# opendata.dwd.de/cli 100%[===================>]  18,29M  11,2MB/s    in 1,6s
# opendata.dwd.de/cli 100%[===================>]  31,23M  11,2MB/s    in 2,8s
# opendata.dwd.de/cli 100%[===================>]  33,58M  10,3MB/s    in 3,2s
# opendata.dwd.de/cli 100%[===================>]  14,83M  11,2MB/s    in 1,3s
# opendata.dwd.de/cli 100%[===================>]  25,82M  11,2MB/s    in 2,3s
# opendata.dwd.de/cli 100%[===================>]  22,65M  11,2MB/s    in 2,0s
# opendata.dwd.de/cli 100%[===================>]  27,61M  10,4MB/s    in 2,6s
# opendata.dwd.de/cli 100%[===================>]  26,06M  11,2MB/s    in 2,3s
# opendata.dwd.de/cli 100%[===================>]  28,49M  11,2MB/s    in 2,5s
# opendata.dwd.de/cli 100%[===================>]  26,70M  11,1MB/s    in 2,4s
# opendata.dwd.de/cli 100%[===================>]  27,84M  11,2MB/s    in 2,5s
# opendata.dwd.de/cli 100%[===================>]  21,29M  11,2MB/s    in 1,9s
# opendata.dwd.de/cli 100%[===================>]  33,64M  11,2MB/s    in 3,0s
# opendata.dwd.de/cli 100%[===================>]  20,37M  11,2MB/s    in 1,8s
# opendata.dwd.de/cli 100%[===================>]  32,43M  11,2MB/s    in 2,9s
# opendata.dwd.de/cli 100%[===================>]  30,01M  11,2MB/s    in 2,7s
# opendata.dwd.de/cli 100%[===================>]  22,53M  10,1MB/s    in 2,2s
# opendata.dwd.de/cli 100%[===================>]  28,72M  11,2MB/s    in 2,6s
# opendata.dwd.de/cli 100%[===================>]  26,23M  11,2MB/s    in 2,3s
# opendata.dwd.de/cli 100%[===================>]  38,01M  10,9MB/s    in 3,5s
# opendata.dwd.de/cli 100%[===================>]  27,33M  10,4MB/s    in 2,6s
# opendata.dwd.de/cli 100%[===================>]  22,26M  11,1MB/s    in 2,0s
# opendata.dwd.de/cli 100%[===================>]  17,06M  11,2MB/s    in 1,5s
# opendata.dwd.de/cli 100%[===================>]  26,69M  11,2MB/s    in 2,4s
# opendata.dwd.de/cli 100%[===================>]  25,55M  11,2MB/s    in 2,3s
# opendata.dwd.de/cli 100%[===================>]  15,76M  9,90MB/s    in 1,6s
# opendata.dwd.de/cli 100%[===================>]  23,04M  11,2MB/s    in 2,1s
# opendata.dwd.de/cli 100%[===================>]  21,36M  10,2MB/s    in 2,1s
# opendata.dwd.de/cli 100%[===================>]  24,70M  11,2MB/s    in 2,2s
# opendata.dwd.de/cli 100%[===================>]  24,90M  11,2MB/s    in 2,2s
# opendata.dwd.de/cli 100%[===================>]  26,39M  10,4MB/s    in 2,5s
# opendata.dwd.de/cli 100%[===================>]  29,17M  11,2MB/s    in 2,6s
# opendata.dwd.de/cli 100%[===================>]  38,46M  11,2MB/s    in 3,4s
# opendata.dwd.de/cli 100%[===================>]  29,87M  10,5MB/s    in 2,9s
# opendata.dwd.de/cli 100%[===================>]  30,43M  11,2MB/s    in 2,7s
# opendata.dwd.de/cli 100%[===================>]  31,70M  11,0MB/s    in 2,9s
# opendata.dwd.de/cli 100%[===================>]  33,47M  11,2MB/s    in 3,0s
# opendata.dwd.de/cli 100%[===================>]  31,49M  10,5MB/s    in 3,0s
# opendata.dwd.de/cli 100%[===================>]  36,62M  11,2MB/s    in 3,3s
# opendata.dwd.de/cli 100%[===================>]  15,00M  11,2MB/s    in 1,3s
# opendata.dwd.de/cli 100%[===================>]  26,42M  11,2MB/s    in 2,4s
# opendata.dwd.de/cli 100%[===================>]  21,96M  10,2MB/s    in 2,1s
# opendata.dwd.de/cli 100%[===================>]  22,12M  11,2MB/s    in 2,0s
# opendata.dwd.de/cli 100%[===================>]  19,89M  11,2MB/s    in 1,8s
# opendata.dwd.de/cli 100%[===================>]  19,50M  11,2MB/s    in 1,7s
# opendata.dwd.de/cli 100%[===================>]  21,31M  11,2MB/s    in 1,9s
# opendata.dwd.de/cli 100%[===================>]  18,96M  10,1MB/s    in 1,9s
# opendata.dwd.de/cli 100%[===================>]  16,42M  11,2MB/s    in 1,5s
# opendata.dwd.de/cli 100%[===================>]  17,07M  11,2MB/s    in 1,5s
# opendata.dwd.de/cli 100%[===================>]  36,59M  10,9MB/s    in 3,4s
# opendata.dwd.de/cli 100%[===================>]  32,07M  11,2MB/s    in 2,9s
# opendata.dwd.de/cli 100%[===================>]  16,68M  10,0MB/s    in 1,7s
# opendata.dwd.de/cli 100%[===================>]  31,59M  11,2MB/s    in 2,8s
# opendata.dwd.de/cli 100%[===================>]  19,53M  11,2MB/s    in 1,7s
# opendata.dwd.de/cli 100%[===================>]  31,27M  11,0MB/s    in 2,8s
# opendata.dwd.de/cli 100%[===================>]  21,55M  9,89MB/s    in 2,2s
# opendata.dwd.de/cli 100%[===================>]  23,29M  11,0MB/s    in 2,1s
# opendata.dwd.de/cli 100%[===================>]  26,56M  11,2MB/s    in 2,4s
# opendata.dwd.de/cli 100%[===================>]  27,82M  10,9MB/s    in 2,5s
# opendata.dwd.de/cli 100%[===================>]  32,86M  10,6MB/s    in 3,1s
# opendata.dwd.de/cli 100%[===================>]  27,65M  10,4MB/s    in 2,7s
# opendata.dwd.de/cli 100%[===================>]  28,59M  11,2MB/s    in 2,6s
# opendata.dwd.de/cli 100%[===================>]  21,47M  11,2MB/s    in 1,9s
# opendata.dwd.de/cli 100%[===================>]  40,14M  11,2MB/s    in 3,6s
# opendata.dwd.de/cli 100%[===================>]  23,99M  10,3MB/s    in 2,3s
# opendata.dwd.de/cli 100%[===================>]  13,51M  11,2MB/s    in 1,2s
# opendata.dwd.de/cli 100%[===================>]  21,49M  11,2MB/s    in 1,9s
# opendata.dwd.de/cli 100%[===================>]  32,59M  11,2MB/s    in 2,9s
# opendata.dwd.de/cli 100%[===================>]  24,22M  11,2MB/s    in 2,2s
# opendata.dwd.de/cli 100%[===================>]  30,27M  11,2MB/s    in 2,7s
# opendata.dwd.de/cli 100%[===================>]  19,27M  11,2MB/s    in 1,7s
# opendata.dwd.de/cli 100%[===================>]  33,10M  11,2MB/s    in 3,0s
# opendata.dwd.de/cli 100%[===================>]  14,72M  8,07MB/s    in 1,8s
# opendata.dwd.de/cli 100%[===================>]  27,08M  10,4MB/s    in 2,6s
# opendata.dwd.de/cli 100%[===================>]  31,37M  11,2MB/s    in 2,8s
# opendata.dwd.de/cli 100%[===================>]  22,44M  11,1MB/s    in 2,0s
# opendata.dwd.de/cli 100%[===================>]  23,81M  11,2MB/s    in 2,1s
# opendata.dwd.de/cli 100%[===================>]  23,08M  11,2MB/s    in 2,1s
# opendata.dwd.de/cli 100%[===================>]  40,93M  10,1MB/s    in 4,0s
# opendata.dwd.de/cli 100%[===================>]  26,33M  10,1MB/s    in 2,6s
# opendata.dwd.de/cli 100%[===================>]  32,55M  11,2MB/s    in 2,9s
# opendata.dwd.de/cli 100%[===================>]  35,22M  11,2MB/s    in 3,2s
# opendata.dwd.de/cli 100%[===================>]  16,59M  11,2MB/s    in 1,5s
# opendata.dwd.de/cli 100%[===================>]  22,34M  11,2MB/s    in 2,0s
# opendata.dwd.de/cli 100%[===================>]  21,66M  10,2MB/s    in 2,1s
# opendata.dwd.de/cli 100%[===================>]  26,10M  11,2MB/s    in 2,3s
# opendata.dwd.de/cli 100%[===================>]  69,33K  --.-KB/s    in 0,005s
# opendata.dwd.de/cli 100%[===================>]  11,44M  11,2MB/s    in 1,0s
# CPU times: user 8.42 s, sys: 1.33 s, total: 9.76 s
# Wall time: 10min 6s

# %%
# delete folder /supplement
# !rm -r -v /home/alexander/Github/scripts/dwd_radar/radklim_rw/data/raklim_rw_binary/opendata.dwd.de/climate_environment/CDC/grids_germany/hourly/radolan/reproc/2017_002/bin/supplement

# %% [markdown]
# ## Read data from nested tar file
#
# Data is provided as monthly tar.gz files, which contains hourly binary files. To avoid extracting everything first we use the nested loop-construct below and extract only the data we want on the fly.
#
# Goal is to produce one netCDF file for the entire temporal and spatial range.
# Data is to be aggregated to **daily sums** later.
#
# DWD infos: https://opendata.dwd.de/climate_environment/CDC/help/landing_pages/doi_landingpage_RADKLIM_RW_V2017.002-de.html

# %% [markdown]
# ### (cf-conform) Metadata dictionary
#
# As the package `radolan_to_netcdf` does not yet support RADKLIM RW, the metadata dictionary is created here.

# %%
from radolan_to_netcdf.radolan_product_netcdf_config import metadata_per_timestamp

raklim_rw_netcdf_config = {
    "variables": {
        "rainfall_amount": {
            "variable_parameters": {
                "datatype": "i2",
                "dimensions": ("time", "y", "x"),
                "fill_value": -9999,
                "zlib": True,
                "complevel": 5,
            },
            "attributes": {
                "long_name": "Hourly rainfall",
                "standard_name": "rainfall_amount",
                "units": "kg",
                "scale_factor": 0.01,
                "add_offset": 0,
                "coordinates": "longitudes latitudes",
                "grid_mapping": "RADOLAN_grid",
            },
        },
    },
    "metadata_per_timestamp": metadata_per_timestamp,
    "metadata_fixed": {
        "n_lats": 1100,
        "n_lons": 900,
    },
}

# %%
# %%time
#from time import time

# absolute output_path to the folder radklim, where netCDF files are saved
#output_path = "data/radklim_rw/"
fn_netcdf = "data/radklim_rw.nc"
rtn.create_empty_netcdf(fn=fn_netcdf, product_config_dict=raklim_rw_netcdf_config)

# create folder radklim_yw
os.makedirs(output_path, exist_ok=True)

for year in sorted(glob('./data/raklim_rw_binary/opendata.dwd.de/climate_environment/CDC/grids_germany/hourly/radolan/reproc/2017_002/bin/*')):
    print(f"Extracting data for the year {year[-4:]}")
    for month in tqdm.tqdm(sorted(glob(year + '/*'))):
        with tarfile.open(month, 'r') as tar:
            # fn_list: filenames of daily files ('YW2017.002_20010131.tar.gz')
            fn_list = sorted([f.name for f in tar.getmembers()])
            #fn_list = sorted(tar.getnames())

            # loop over daily files
            for fn in fn_list:
                f = tar.extractfile(fn)
                # create (empty) daily netCDF
                fn_netcdf = f"{output_path}/{fn[-15:-7]}_radklim_yw.nc"
                # t1 = time()
                rtn.create_empty_netcdf(fn=fn_netcdf, product_name='YW')
                # t2=time()
                #print(f"create_empty_netcdf: {time() - t1}")
                # daily files contain the 5-minute data (tar_inner)
                with tarfile.open(fileobj=f) as tar_inner:
                    # t1 = time()
                    # fn_list_inner = sorted(tar_inner.getnames())
                    # print(f"tar_inner.getnames: {time() - t1}")
                    # t1 = time()
                    fn_list_inner = sorted([f.name for f in tar_inner.getmembers()])
                    # print(f"tar_inner.getmembers: {time() - t1}")

                    for fn_inner in fn_list_inner:
                        # extract 5-minute data, append to previously created daily netCDF
                        # t1 = time()
                        data, metadata = rtn.read_in_one_bin_file(tar_inner.extractfile(fn_inner))
                        # print(f"read_in_one_bin_file: {time() - t1}")
                        # t1 = time()
                        rtn.append_to_netcdf(
                            fn_netcdf, 
                            data_list=[data, ], 
                            metadata_list=[metadata, ],
                        )
                        # print(f"append_to_netcdf: {time() - t1}")

# %%
def tar2netcdf(input_path: str, output_path: str, radklim_rw_config: dict):
    """
    Untar DWD binary downloads and store as one netCDF files under path.

    Parameters:
    ------
    input_path: str 
        path to the folder where binary DWD downloads are stored (yearly folders).
        Usually something like *"./opendata.dwd.de/climate_environment/CDC/grids_germany/5_minutes/radolan/reproc/2017_002/bin"*
    output_path: str
        where to store generated netCDF file
    radklim_rw_config : dict
        Dictionary holding the parameters required for building a NetCDF file with the correct dimensions, 
        variables names and attributes (see package radolan_to_netcdf).
    """
    # create folder in output path
    os.makedirs(output_path, exist_ok=True)

    # get the absolute output_path to the folder radklim_rw, where netCDF files are saved
    output_path = os.path.abspath(output_path)

    fn_netcdf = f"{output_path}/radklim_rw.nc"

    rtn.create_empty_netcdf(fn=fn_netcdf, product_config_dict=radklim_rw_config, product_name="RW")

    # loop over yearly files
    for year in sorted(glob(f"{input_path}/*")):
        print(f"Extracting data for the year {year[-4:]}")
        for month in tqdm.tqdm(sorted(glob(year + '/*'))):
            with tarfile.open(month, 'r') as tar:
                # fn_list: filenames of hourly files ('raa01-rw2017.002_10000-0101010050-dwd---bin')
                fn_list = sorted([f.name for f in tar.getmembers()])

                # loop over hourly files, append to netcdf
                for fn in fn_list:
                    data, metadata = rtn.read_in_one_bin_file(tar.extractfile(fn))
                    rtn.append_to_netcdf(
                        fn_netcdf,
                        data_list=[data, ],
                        metadata_list=[metadata, ]
                    )

# %% [markdown]
# Execute `tar2netcdf` to extract data and save to one netCDF file.

# %%
tar2netcdf(input_path="data/raklim_rw_binary/opendata.dwd.de/climate_environment/CDC/grids_germany/hourly/radolan/reproc/2017_002/bin/",
           output_path="data/radklim_rw/",
           radklim_rw_config=raklim_rw_netcdf_config)
# Out:
# Extracting data for the year 2001
#   0%|          | 0/12 [00:34<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 tar2netcdf(input_path="data/raklim_rw_binary/opendata.dwd.de/climate_environment/CDC/grids_germany/hourly/radolan/reproc/2017_002/bin/",
#       2            output_path="data/radklim_rw/",
#       3            radklim_rw_config=raklim_rw_netcdf_config)
#
# Cell In [13], line 36, in tar2netcdf(input_path, output_path, radklim_rw_config)
#      34 # loop over hourly files, append to netcdf
#      35 for fn in fn_list:
# ---> 36     data, metadata = rtn.read_in_one_bin_file(tar.extractfile(fn))
#      37     rtn.append_to_netcdf(
#      38         fn_netcdf,
#      39         data_list=[data, ],
#      40         metadata_list=[metadata, ]
#      41     )
#
# File ~/Github/radolan_to_netcdf/radolan_to_netcdf/radolan_to_netcdf.py:142, in read_in_one_bin_file(f)
#     141 def read_in_one_bin_file(f):
# --> 142     data, metadata = wrl.io.read_radolan_composite(f, missing=np.nan)
#     143     return data, metadata
#
# File ~/anaconda3/envs/wradlib/lib/python3.10/site-packages/wradlib/io/radolan.py:763, in read_radolan_composite(f, missing, loaddata, fillmissing)
#     760 NODATA = missing
#     762 # get _radolan_file class
# --> 763 with _radolan_file(
#     764     f, fillmissing=fillmissing, copy=True, ancillary=False
#     765 ) as radfile:
#     767     attrs = radfile.attrs
#     769     if not loaddata:
#
# File ~/anaconda3/envs/wradlib/lib/python3.10/site-packages/wradlib/io/radolan.py:1016, in _radolan_file.__init__(self, filename, fillmissing, copy, ancillary)
#    1014 self._fill = fillmissing
#    1015 self._copy = copy
# -> 1016 self._ancillary = self._get_ancillary(requested=ancillary)
#
# File ~/anaconda3/envs/wradlib/lib/python3.10/site-packages/wradlib/io/radolan.py:1190, in _radolan_file._get_ancillary(self, requested)
#    1189 def _get_ancillary(self, requested=True):
# -> 1190     if self.product in ["PG", "PC"]:
#    1191         anc = ("nodatamask",)
#    1192     elif self.product in ["RX", "EX", "WX"]:
#
# File ~/anaconda3/envs/wradlib/lib/python3.10/site-packages/wradlib/io/radolan.py:1029, in _radolan_file.product(self)
#    1026 @property
#    1027 def product(self):
#    1028     if self._product is None:
# -> 1029         self._product = self.attrs["producttype"]
#    1030     return self._product
#
# File ~/anaconda3/envs/wradlib/lib/python3.10/site-packages/wradlib/io/radolan.py:1023, in _radolan_file.attrs(self)
#    1020 if self._attrs is None:
#    1021     # move file pointer to start
#    1022     self.fp.seek(0)
# -> 1023     self._attrs = self._read_attrs()
#    1024 return self._attrs
#
# File ~/anaconda3/envs/wradlib/lib/python3.10/site-packages/wradlib/io/radolan.py:1062, in _radolan_file._read_attrs(self)
#    1061 def _read_attrs(self):
# -> 1062     header = read_radolan_header(self.fp)
#    1063     return parse_dwd_composite_header(header)
#
# File ~/anaconda3/envs/wradlib/lib/python3.10/site-packages/wradlib/io/radolan.py:688, in read_radolan_header(fid)
#     686 header = ""
#     687 while True:
# --> 688     mychar = fid.read(1)
#     689     if not mychar:
#     690         raise EOFError("Unexpected EOF detected while reading " "RADOLAN header")
#
# File ~/anaconda3/envs/wradlib/lib/python3.10/tarfile.py:696, in _FileInFile.readinto(self, b)
#     695 def readinto(self, b):
# --> 696     buf = self.read(len(b))
#     697     b[:len(buf)] = buf
#     698     return len(buf)
#
# File ~/anaconda3/envs/wradlib/lib/python3.10/tarfile.py:684, in _FileInFile.read(self, size)
#     682 length = min(size, stop - self.position)
#     683 if data:
# --> 684     self.fileobj.seek(offset + (self.position - start))
#     685     b = self.fileobj.read(length)
#     686     if len(b) != length:
#
# File ~/anaconda3/envs/wradlib/lib/python3.10/gzip.py:393, in GzipFile.seek(self, offset, whence)
#     391 elif self.mode == READ:
#     392     self._check_not_closed()
# --> 393     return self._buffer.seek(offset, whence)
#     395 return self.offset
#
# File ~/anaconda3/envs/wradlib/lib/python3.10/_compression.py:153, in DecompressReader.seek(self, offset, whence)
#     151 # Read and discard data until we reach the desired position.
#     152 while offset > 0:
# --> 153     data = self.read(min(io.DEFAULT_BUFFER_SIZE, offset))
#     154     if not data:
#     155         break
#
# File ~/anaconda3/envs/wradlib/lib/python3.10/gzip.py:496, in _GzipReader.read(self, size)
#     493 # Read a chunk of data from the file
#     494 buf = self._fp.read(io.DEFAULT_BUFFER_SIZE)
# --> 496 uncompress = self._decompressor.decompress(buf, size)
#     497 if self._decompressor.unconsumed_tail != b"":
#     498     self._fp.prepend(self._decompressor.unconsumed_tail)
#
# KeyboardInterrupt:

# %%
xr.open_dataset("data/radklim_rw/radklim_rw.nc")
# Out:
# <xarray.Dataset>
# Dimensions:          (x: 900, y: 1100, time: 15)
# Coordinates:
#   * x                (x) float64 -443.5 -442.5 -441.5 ... 453.5 454.5 455.5
#   * y                (y) float64 -4.759e+03 -4.758e+03 ... -3.661e+03 -3.66e+03
#     latitudes        (y, x) float64 ...
#     longitudes       (y, x) float64 ...
#   * time             (time) datetime64[ns] 2001-01-01T00:50:00 ... 2001-01-01...
# Data variables:
#     rainfall_amount  (time, y, x) float32 ...
#     maxrange         (time) int16 ...
#     secondary        (time, y, x) float32 ...
#     nodatamask       (time, y, x) float32 ...
#     cluttermask      (time, y, x) float32 ...
#     radolan_grid     float64 ...
# Attributes:
#     title:        RADOLAN RW rainfall data
#     producttype:  RW
#     institution:  Deutscher Wetterdienst (DWD)
#     history:      Created at 2022-12-20 12:35:41.933149
#     Conventions:  CF-1.6

# %% [markdown]
# ## hourly rainfall to daily rainfall
